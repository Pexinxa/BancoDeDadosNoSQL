# %% [markdown]
# FONTE: SINAN/DATASUS — datasus.saude.gov.br

# %% [markdown]
# Instalação

# %%
# !pip install pymongo dnspython folium streamlit pyngrok -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 22.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 84.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 93.5 MB/s eta 0:00:00

# %% [markdown]
# Importações

# %%
import json
import folium
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from pymongo import MongoClient
from IPython.display import display

# %% [markdown]
# Conexão com o Atlas

# %%
MONGO_URI = "mongodb+srv://user:password@clusterdsm.wnqzyqd.mongodb.net/?appName=ClusterDSM"

client = MongoClient(MONGO_URI)
db     = client["dengue_db"]
col    = db["dengue_2015"]

print(f"✅ Conectado! {col.count_documents({})} documentos na coleção.")
# Out:
# ✅ Conectado! 0 documentos na coleção.

# %%
with open("dengue_brasil_2015.json", "r", encoding="utf-8") as f:
    dados = json.load(f)

col.insert_many(dados)
print(f"✅ {col.count_documents({})} documentos inseridos!")
# Out:
# ✅ 27 documentos inseridos!

# %% [markdown]
# Agrupamento por região

# %%
pipeline = [
    {
        "$group": {
            "_id": "$regiao",
            "total_casos": {"$sum": "$casos_confirmados"},
            "media_casos": {"$avg": "$casos_confirmados"},
            "num_estados": {"$sum": 1}
        }
    },
    {"$sort": {"total_casos": -1}}
]

resultado = list(col.aggregate(pipeline))

print(f"{'Região':<15} {'Total de Casos':>15} {'Média por Estado':>18} {'Nº Estados':>12}")
print("-" * 65)
for r in resultado:
    print(f"{r['_id']:<15} {r['total_casos']:>15,} {r['media_casos']:>18,.0f} {r['num_estados']:>12}")
# Out:
# Região           Total de Casos   Média por Estado   Nº Estados
# -----------------------------------------------------------------
# Sudeste               1,487,238            371,810            4
# Nordeste                777,875             86,431            9
# Centro-Oeste            327,522             81,880            4
# Sul                     269,886             89,962            3
# Norte                   144,054             20,579            7

# %% [markdown]
# Mapa 1 (total por região)

# %%
centros = {
    "Norte":        (-3.4653,  -62.2159),
    "Nordeste":     (-8.0476,  -34.8770),
    "Centro-Oeste": (-15.7801, -47.9292),
    "Sudeste":      (-19.9167, -43.9345),
    "Sul":          (-25.4284, -49.2733),
}

totais = {r["_id"]: r["total_casos"] for r in resultado}

mapa1 = folium.Map(location=[-14.2, -51.9], zoom_start=4, tiles="CartoDB positron")

for regiao, (lat, lon) in centros.items():
    total = totais.get(regiao, 0)
    folium.CircleMarker(
        location=[lat, lon],
        radius=15,
        color="#c0392b",
        fill=True,
        fill_color="#e74c3c",
        fill_opacity=0.75,
        tooltip=f"<b>{regiao}</b><br>Total: {total:,} casos",
        popup=folium.Popup(f"<b>Região {regiao}</b><br>Total: <b>{total:,}</b>", max_width=220)
    ).add_to(mapa1)

    folium.Marker(
        location=[lat, lon],
        icon=folium.DivIcon(
            html=f'<div style="font-size:10px;font-weight:bold;color:#c0392b;white-space:nowrap">{total:,}</div>',
            icon_size=(120, 20),
            icon_anchor=(0, -10)
        )
    ).add_to(mapa1)

display(mapa1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ab52aa4a8dfa67e5e3b5df8d8740fba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ab52aa4a8dfa67e5e3b5df8d8740fba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ab52aa4a8dfa67e5e3b5df8d8740fba = L.map(
#                 &quot;map_9ab52aa4a8dfa67e5e3b5df8d8740fba&quot;,
#                 {
#                     center: [-14.2, -51.9],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31fa2cd86048e034c54cc878810edb70 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_31fa2cd86048e034c54cc878810edb70.addTo(map_9ab52aa4a8dfa67e5e3b5df8d8740fba);
#
#
#             var circle_marker_8fa1deb5a71ae57358c46f753a7913d0 = L.circleMarker(
#                 [-3.4653, -62.2159],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#c0392b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 0.75, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9ab52aa4a8dfa67e5e3b5df8d8740fba);
#
#
#         var popup_1571bbf200387ea75a3fbfed479a7c4b = L.popup({
#   &quot;maxWidth&quot;: 220,
# });
#
#
#
#                 var html_6c4c481b8fb43924da6d23447e9b7772 = $(`&lt;div id=&quot;html_6c4c481b8fb43924da6d23447e9b7772&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Região Norte&lt;/b&gt;&lt;br&gt;Total: &lt;b&gt;144,054&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_1571bbf200387ea75a3fbfed479a7c4b.setContent(html_6c4c481b8fb43924da6d23447e9b7772);
#
#
#
#         circle_marker_8fa1deb5a71ae57358c46f753a7913d0.bindPopup(popup_1571bbf200387ea75a3fbfed479a7c4b)
#         ;
#
#
#
#
#             circle_marker_8fa1deb5a71ae57358c46f753a7913d0.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Norte&lt;/b&gt;&lt;br&gt;Total: 144,054 casos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c6927208380c6ebe467024230a09ae59 = L.marker(
#                 [-3.4653, -62.2159],
#                 {
# }
#             ).addTo(map_9ab52aa4a8dfa67e5e3b5df8d8740fba);
#
#
#             var div_icon_83e5643bad3fe3bbba66749589a72eb5 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size:10px;font-weight:bold;color:#c0392b;white-space:nowrap\&quot;\u003e144,054\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [120, 20],
#   &quot;iconAnchor&quot;: [0, -10],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_c6927208380c6ebe467024230a09ae59.setIcon(div_icon_83e5643bad3fe3bbba66749589a72eb5);
#
#
#             var circle_marker_14916d2b112df3c8262677c59957b1cc = L.circleMarker(
#                 [-8.0476, -34.877],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#c0392b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 0.75, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9ab52aa4a8dfa67e5e3b5df8d8740fba);
#
#
#         var popup_2f0e8ce3d178af5f0fcd8db44dabac62 = L.popup({
#   &quot;maxWidth&quot;: 220,
# });
#
#
#
#                 var html_508ab7a8308f5757d802fb0330c4fd8a = $(`&lt;div id=&quot;html_508ab7a8308f5757d802fb0330c4fd8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Região Nordeste&lt;/b&gt;&lt;br&gt;Total: &lt;b&gt;777,875&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_2f0e8ce3d178af5f0fcd8db44dabac62.setContent(html_508ab7a8308f5757d802fb0330c4fd8a);
#
#
#
#         circle_marker_14916d2b112df3c8262677c59957b1cc.bindPopup(popup_2f0e8ce3d178af5f0fcd8db44dabac62)
#         ;
#
#
#
#
#             circle_marker_14916d2b112df3c8262677c59957b1cc.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Nordeste&lt;/b&gt;&lt;br&gt;To

# %% [markdown]
# Gráfico de média por região

# %%
regioes = [r["_id"]        for r in resultado]
medias  = [r["media_casos"] for r in resultado]

cores = ["#2980b9", "#27ae60", "#e67e22", "#8e44ad", "#c0392b"]

fig, ax = plt.subplots(figsize=(9, 5))
bars = ax.bar(regioes, medias, color=cores, edgecolor="white", linewidth=0.8)

for bar, val in zip(bars, medias):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 2000,
            f"{val:,.0f}", ha="center", va="bottom", fontsize=9, fontweight="bold")

ax.set_title("Média de casos de dengue por estado em cada região — Brasil 2015",
             fontsize=12, fontweight="bold", pad=14)
ax.set_xlabel("Região", fontsize=10)
ax.set_ylabel("Média de casos confirmados", fontsize=10)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x:,.0f}"))
ax.set_ylim(0, max(medias) * 1.18)
ax.spines[["top", "right"]].set_visible(False)
plt.tight_layout()
plt.savefig("grafico_media_regiao.png", dpi=150)
plt.show()

# %% [markdown]
# Mapa 2 (cidades do Sudeste)

# %%
cidades_sudeste = [
    {"cidade": "São Paulo - SP",      "lat": -23.5505, "lon": -46.6333, "casos": 119_876},
    {"cidade": "Rio de Janeiro - RJ", "lat": -22.9068, "lon": -43.1729, "casos": 95_432},
    {"cidade": "Belo Horizonte - MG", "lat": -19.9191, "lon": -43.9386, "casos": 44_231},
    {"cidade": "Campinas - SP",       "lat": -22.9056, "lon": -47.0608, "casos": 31_745},
    {"cidade": "Guarulhos - SP",      "lat": -23.4543, "lon": -46.5333, "casos": 27_890},
    {"cidade": "Ribeirão Preto - SP", "lat": -21.1775, "lon": -47.8103, "casos": 17_654},
    {"cidade": "Sorocaba - SP",       "lat": -23.5015, "lon": -47.4526, "casos": 14_987},
    {"cidade": "Niterói - RJ",        "lat": -22.8833, "lon": -43.1036, "casos": 11_320},
]

mapa2 = folium.Map(location=[-21.5, -44.5], zoom_start=6, tiles="CartoDB positron")

for c in cidades_sudeste:
    raio = 6 + (c["casos"] / 15_000)
    folium.CircleMarker(
        location=[c["lat"], c["lon"]],
        radius=raio,
        color="#922b21",
        fill=True,
        fill_color="#e74c3c",
        fill_opacity=0.7,
        tooltip=f"<b>{c['cidade']}</b><br>{c['casos']:,} casos",
        popup=folium.Popup(f"<b>{c['cidade']}</b><br>Casos: <b>{c['casos']:,}</b>", max_width=220)
    ).add_to(mapa2)

display(mapa2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e2fa62bbc1196fef40ba6ac7564494b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e2fa62bbc1196fef40ba6ac7564494b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e2fa62bbc1196fef40ba6ac7564494b = L.map(
#                 &quot;map_5e2fa62bbc1196fef40ba6ac7564494b&quot;,
#                 {
#                     center: [-21.5, -44.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20d192ceab69c3f01152527be2814c04 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_20d192ceab69c3f01152527be2814c04.addTo(map_5e2fa62bbc1196fef40ba6ac7564494b);
#
#
#             var circle_marker_15536f70102dbaffbb812e7cddd62adb = L.circleMarker(
#                 [-23.5505, -46.6333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#922b21&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.991733333333332, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5e2fa62bbc1196fef40ba6ac7564494b);
#
#
#         var popup_4fdf6d8da11f058b0f1e5ee811aef9f9 = L.popup({
#   &quot;maxWidth&quot;: 220,
# });
#
#
#
#                 var html_de6de152528d4acb308581bfdb6e803e = $(`&lt;div id=&quot;html_de6de152528d4acb308581bfdb6e803e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;São Paulo - SP&lt;/b&gt;&lt;br&gt;Casos: &lt;b&gt;119,876&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_4fdf6d8da11f058b0f1e5ee811aef9f9.setContent(html_de6de152528d4acb308581bfdb6e803e);
#
#
#
#         circle_marker_15536f70102dbaffbb812e7cddd62adb.bindPopup(popup_4fdf6d8da11f058b0f1e5ee811aef9f9)
#         ;
#
#
#
#
#             circle_marker_15536f70102dbaffbb812e7cddd62adb.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;São Paulo - SP&lt;/b&gt;&lt;br&gt;119,876 casos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_aa76535cd60c0b928bc39cad7c95ce6c = L.circleMarker(
#                 [-22.9068, -43.1729],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#922b21&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.362133333333333, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5e2fa62bbc1196fef40ba6ac7564494b);
#
#
#         var popup_8a5a9d637903b3846b57c7ec74aa4be9 = L.popup({
#   &quot;maxWidth&quot;: 220,
# });
#
#
#
#                 var html_caed892e2df647daf90ac4a2d0a94911 = $(`&lt;div id=&quot;html_caed892e2df647daf90ac4a2d0a94911&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Rio de Janeiro - RJ&lt;/b&gt;&lt;br&gt;Casos: &lt;b&gt;95,432&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_8a5a9d637903b3846b57c7ec74aa4be9.setContent(html_caed892e2df647daf90ac4a2d0a94911);
#
#
#
#         circle_marker_aa76535cd60c0b928bc39cad7c95ce6c.bindPopup(popup_8a5a9d637903b3846b57c7ec74aa4be9)
#         ;
#
#
#
#
#             circle_marker_aa76535cd60c0b928bc39cad7c95ce6c.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Rio de Janeiro - RJ&lt;/b&gt;&lt;br&gt;95,432 casos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_13584ffdc9dd654bdfa9678caf9fafe7 = L.circleMarker(
#                 [-19.9191, -43.9386],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#922b21&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;
